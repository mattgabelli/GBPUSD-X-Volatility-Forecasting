# %%
# Plot the historical volatility data
import matplotlib.pyplot as plt
import 

plt.figure(figsize=(10, 6))
plt.plot(forex_data.index, forex_data["Close"])
plt.xlabel("Date")
plt.ylabel("Volatility")
plt.title("Historical Volatility Data")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(10, 6))
# ----> 5 plt.plot(forex_data.index, forex_data["Close"])
#       6 plt.xlabel("Date")
#       7 plt.ylabel("Volatility")
#
# NameError: name 'forex_data' is not defined
